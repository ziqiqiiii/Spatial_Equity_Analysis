# %%
import pandas as pd
import geopandas as gpd
from geopandas import GeoDataFrame
import numpy as np

# %%
# CRITICAL: Singapore's Projected Coordinate System (Metric)
# We MUST use this. Do not use EPSG:4326 (Lat/Lon).
CRS_PROJ = "EPSG:3414"

# %%
raw_path = "../data/data_raw/"

# %% [markdown]
# - From the HDB report (refer to HDB_Key_Statistics_2025.pdf in data/data_raw), the total HDB population is 3,190,590 (3.2 million).

# %%
hdb_population = 3190590

# %%
planning_area = gpd.read_file(f"{raw_path}MasterPlan2019PlanningAreaBoundaryNoSea.geojson")
subzone = gpd.read_file(f"{raw_path}MasterPlan2019SubzoneBoundaryNoSeaGEOJSON.geojson")
sport_facilities  = gpd.read_file(f"{raw_path}SportSGSportFacilitiesGEOJSON.geojson")
parks = gpd.read_file(f"{raw_path}NParksParksandNatureReserves.geojson")
park_connector = gpd.read_file(f"{raw_path}ParkConnectorLoop.geojson")
cycling_paths = gpd.read_file(f"{raw_path}CyclingPathNetwork.geojson")
hdb = gpd.read_file(f"{raw_path}HDBExistingBuilding.geojson")

# %%
print("HDB")
display(hdb.head())

print("Planning Area")
display(planning_area.head())

print("sport_facilities")
display(sport_facilities.head())

print("parks")
display(parks.head())

print("cycling_paths")
display(cycling_paths.head())

print("park_connector")
display(park_connector.head())
# Out:
# HDB
#    name                                           geometry
# 0  Path  LINESTRING (103.8017 1.44919, 103.80169 1.4491...
# 1  Path  LINESTRING (103.75023 1.35897, 103.75033 1.359...
# 2  Path  LINESTRING (103.95811 1.35344, 103.95812 1.353...
# 3  Path  LINESTRING (103.74972 1.39435, 103.74967 1.394...
# 4  Path  LINESTRING (103.81731 1.27887, 103.81735 1.278...
# Planning Area
#     Name                                        Description  \
# 0  kml_1  <center><table><tr><th colspan='2' align='cent...
# 1  kml_2  <center><table><tr><th colspan='2' align='cent...
# 2  kml_3  <center><table><tr><th colspan='2' align='cent...
# 3  kml_4  <center><table><tr><th colspan='2' align='cent...
# 4  kml_5  <center><table><tr><th colspan='2' align='cent...
#
#                                             geometry
# 0  POLYGON Z ((103.93208 1.30555 0, 103.93208 1.3...
# 1  POLYGON Z ((103.72042 1.32824 0, 103.72003 1.3...
# 2  POLYGON Z ((103.76408 1.37001 0, 103.76444 1.3...
# ...

# %%
def clean_data( gdf: GeoDataFrame, crs_projection=CRS_PROJ) -> GeoDataFrame:
    """
    Clean a GeoDataFrame with geometry-aware handling.

    - Reprojects to `crs_projection`
    - Lowercases column names
    - Drops NA geometries
    - For polygons: fixes invalids via buffer(0), drops empties/invalids, computes area (>0)
    - For lines: keeps valid non-empty lines, computes length

    Parameters
    ----------
    gdf : GeoDataFrame
    crs_projection : Any CRS that GeoPandas/Shapely accepts
    """
    # Reproject & standardize columns
    gdf = gdf.to_crs(crs_projection)
    gdf.columns = gdf.columns.str.lower()

    # Drop NA geometries early
    gdf = gdf[gdf.geometry.notna()].copy()

    # Normalize expected_geom
    expected_geom = gdf.geometry.geom_type.str
    eg = str(expected_geom).lower()

    if eg in ("polygon", "multipolygon"):
        # Keep only polygonal geometries
        poly_mask = gdf.geometry.geom_type.str.contains("Polygon", case=False)
        gdf = gdf[poly_mask].copy()

        # Fix invalid polygon geometries; buffer(0) may collapse bad shapes -> empty
        gdf["geometry"] = gdf.buffer(0)

        # Drop invalids and empties produced by buffer(0)
        gdf = gdf[gdf.geometry.is_valid & ~gdf.geometry.is_empty].copy()

        # Compute area and keep positive-area polygons
        gdf["area"] = gdf.geometry.area
        gdf = gdf[gdf["area"] > 0].copy()

    elif eg in ("linestring", "multilinestring"):
        # Keep only line geometries
        line_mask = gdf.geometry.geom_type.str.contains("LineString", case=False)
        gdf = gdf[line_mask].copy()

        # Do NOT buffer(0) for lines; zero-width buffer collapses to empty
        gdf = gdf[gdf.geometry.is_valid & ~gdf.geometry.is_empty].copy()

        # Length is the relevant metric for lines
        gdf["length"] = gdf.geometry.length

    else:
        # Fallback: return valid, non-empty geometries without area/length enrichment
        gdf = gdf[gdf.geometry.is_valid & ~gdf.geometry.is_empty].copy()

    return gdf

# %%
planning_area = clean_data(planning_area)
subzone = clean_data(subzone)
sport_facilities = clean_data(sport_facilities)
park_connector = clean_data(park_connector)
parks = clean_data(parks)
cycling_paths = clean_data(cycling_paths)
hdb = clean_data(hdb)

# %%
print("HDB")
display(hdb.head())

print("Planning Area")
display(planning_area.head())

print("sport_facilities")
display(sport_facilities.head())

print("parks")
display(parks.head())

print("cycling_paths")
display(cycling_paths.head())

print("park_connector")
display(park_connector.head())
# Out:
# HDB
#    name                                           geometry
# 0  Path  LINESTRING (24481.043 47869.63, 24480.427 4786...
# 1  Path  LINESTRING (18753.211 37893.756, 18764.786 379...
# 2  Path  LINESTRING (41887.998 37282.122, 41889.532 372...
# 3  Path  LINESTRING (18696.214 41806.326, 18691.537 418...
# 4  Path  LINESTRING (26218.761 29036.217, 26222.34 2904...
# Planning Area
#     name                                        description  \
# 1  kml_2  <center><table><tr><th colspan='2' align='cent...
# 2  kml_3  <center><table><tr><th colspan='2' align='cent...
# 4  kml_5  <center><table><tr><th colspan='2' align='cent...
# 5  kml_6  <center><table><tr><th colspan='2' align='cent...
# 6  kml_7  <center><table><tr><th colspan='2' align='cent...
#
#                                             geometry
# 1  POLYGON Z ((15436.019 34495.789 0, 15391.952 3...
# 2  POLYGON Z ((20294.455 39114.528 0, 20334.318 3...
# 4  POLYGON Z ((21448.724 41356.741 0, 21508.535 4...
# ...

# %%
# Count number of HDB buildings
hdb_num = len(hdb)
hdb_unit_num = 1153080
hdb_population_per_block = hdb_population / hdb_num
hdb_population_per_unit = hdb_population / hdb_unit_num

print(f"Number of HDB buildings: {hdb_num}")
print(f"Rough estimation of population per HDB block: {hdb_population_per_block}")
print(f"Number of HDB units: {hdb_unit_num}")
print(f"Rough estimation of population per HDB unit: {hdb_population_per_unit}")
# Out:
# Number of HDB buildings: 13160
# Rough estimation of population per HDB block: 242.44604863221883
# Number of HDB units: 1153080
# Rough estimation of population per HDB unit: 2.7670152981579768

# %%
# Add population column to HDB geodataframe (per-block estimate)
hdb['population'] = hdb_population_per_block
hdb.head()
# Out:
#    name                                           geometry  population
# 0  Path  LINESTRING (24481.043 47869.63, 24480.427 4786...  242.446049
# 1  Path  LINESTRING (18753.211 37893.756, 18764.786 379...  242.446049
# 2  Path  LINESTRING (41887.998 37282.122, 41889.532 372...  242.446049
# 3  Path  LINESTRING (18696.214 41806.326, 18691.537 418...  242.446049
# 4  Path  LINESTRING (26218.761 29036.217, 26222.34 2904...  242.446049

# %%
# # Extract the Planning Area Name from the HTML Description
# Pattern: <th>PLN_AREA_N</th> <td>BEDOK</td>
planning_area['name'] = planning_area['description'].str.extract(r'<th>PLN_AREA_N</th> <td>(.*?)</td>')
sport_facilities['name'] = sport_facilities['description'].str.extract(r'<th>SPORTS_CEN<\/th> <td>(.*?)</td>')
# Display the new column to verify

display(planning_area.head())
display(sport_facilities.head())
# Out:
#                       name                                        description  \
# 1                 BOON LAY  <center><table><tr><th colspan='2' align='cent...
# 2              BUKIT BATOK  <center><table><tr><th colspan='2' align='cent...
# 4            BUKIT PANJANG  <center><table><tr><th colspan='2' align='cent...
# 5              BUKIT TIMAH  <center><table><tr><th colspan='2' align='cent...
# 6  CENTRAL WATER CATCHMENT  <center><table><tr><th colspan='2' align='cent...
#
#                                             geometry
# 1  POLYGON Z ((15436.019 34495.789 0, 15391.952 3...
# 2  POLYGON Z ((20294.455 39114.528 0, 20334.318 3...
# 4  POLYGON Z ((21448.724 41356.741 0, 21508.535 4...
# 5  POLYGON Z ((24031.387 36694.742 0, 24076.658 3...
# 6  POLYGON Z ((25073.293 43675.363 0, 25130.764 4...
#                              name  \
# 0                Clementi Stadium
# 1          Clementi Sports Centre
# 2       Jurong West Sports Centre
# 3  Kallang Basin Swimming Complex
# ...

# %%
def drop_description(gdf: GeoDataFrame) -> GeoDataFrame:
    if 'description' in gdf.columns:
        gdf = gdf.drop(columns=['description'])

    return gdf

# %%
gdf_list = [planning_area, sport_facilities, parks, park_connector, cycling_paths, hdb]

gdf_list = [drop_description(gdf) for gdf in gdf_list]

planning_area, sport_facilities, parks, park_connector, cycling_paths, hdb = gdf_list

# %%
file_path = "../data/data_cleaned/"

planning_area_file_path  = f"{file_path}planning_area.geojson"
sport_facilities_file_path  = f"{file_path}sport_facilities.geojson"
parks_file_path  = f"{file_path}parks.geojson"
park_connector_file_path  = f"{file_path}park_connector.geojson"
cycling_paths_file_path  = f"{file_path}cycling_paths.geojson"
hdb_file_path  = f"{file_path}hdb.geojson"

# %%
planning_area.to_file(planning_area_file_path, driver="GeoJSON")
sport_facilities.to_file(sport_facilities_file_path, driver="GeoJSON")
parks.to_file(parks_file_path, driver="GeoJSON")
park_connector.to_file(park_connector_file_path, driver="GeoJSON")
cycling_paths.to_file(cycling_paths_file_path, driver="GeoJSON")
planning_area.to_file(planning_area_file_path, driver="GeoJSON")
hdb.to_file(hdb_file_path, driver="GeoJSON")

# %%
facilities_num = len(sport_facilities) + len(parks) + len(park_connector) + len(cycling_paths)
facilities_num
# Out:
# 5635

# %%
import networkx as nx
import osmnx as ox

# %%
place_name = "Singapore"
network_type = "walk"
G = ox.graph_from_place(place_name, network_type=network_type)
G_proj = ox.project_graph(G, to_crs=CRS_PROJ)
G_nodes_proj, G_edges_proj = ox.graph_to_gdfs(G_proj, nodes=True, edges=True)

G_nodes_proj = G_nodes_proj.to_crs("EPSG:4326")
G_edges_proj = G_edges_proj.to_crs("EPSG:4326")

# %%
graph_file_path = f"{file_path}singapore_walk_graph.graphml"
nodes_file_path  = f"{file_path}singapore_walk_graph_nodes.geojson"
edges_file_path  = f"{file_path}singapore_walk_graph_edges.geojson"

# Use OSMnx's serializer to handle non-primitive attributes (CRS, geometries)
ox.save_graphml(G_proj, filepath=graph_file_path)
G_nodes_proj.to_file(nodes_file_path, driver="GeoJSON")
G_edges_proj.to_file(edges_file_path, driver="GeoJSON")
