# %%
from google.colab import userdata
from getpass import getpass
import os

# %%
# !rm -rf Equity_Analysis

# %%
# Try to get the token from Colab Secrets, otherwise prompt for it
try:
    token = userdata.get("GITHUB_TOKEN")
    print("Token retrieved from Colab Secrets.")
except:
    print("Enter your GitHub Personal Access Token (PAT):")
    token = getpass()
# Out:
# Enter your GitHub Personal Access Token (PAT):

# %%
# Clone the repository
repo_url = f"https://{token}@github.com/ziqiqiiii/Equity_Analysis.git"
# !git clone {repo_url} || true

# Change directory
# %cd Equity_Analysis
# !git pull
# Out:
# Cloning into 'Equity_Analysis'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 82 (delta 24), reused 59 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (82/82), 19.97 MiB | 14.66 MiB/s, done.
# remote: Total 82 (delta 24), reused 59 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (82/82), 19.97 MiB | 14.66 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Resolving deltas: 100% (24/24), done.
# /content/Equity_Analysis
# /content/Equity_Analysis
# Already up to date.
# Already up to date.

# %%
# Install dependencies
# Based on the libraries used in the project (geopandas, pandas, etc.)
# !pip install geopandas pandas beautifulsoup4 shapely folium mapclassify matplotlib rtree pyproj --quiet
